# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This flexural stress cannot be found using the usual $\sigma = \frac{M y}{I}$ formula because we do not know the $M$. Instead, we have

# %%
D = 1.25
d = 6e-3

rho = D/2 - d/2

E = 200e9

sigma = E*d/2/rho
display(sigma)
# Out:
# 964630225.0803858

# %%
from math import pi

# %%
I = 1/4*pi*(d/2)**4
M = E*I/rho
display(M)
# Out:
# 20.45570779266666
